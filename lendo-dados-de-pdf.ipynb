# %% [markdown]
# ## Lendo tabelas dentro de PDFs
#
# ### Vamos testar com 2 PDFs diferentes

# %%
# Vamos baixar a lib 'tabula' para podermos ler os PDF
# !pip install tabula-py
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached tabula_py-2.7.0-py3-none-any.whl (12.0 MB)
# ...
#   Using cached distro-1.8.0-py3-none-any.whl (20 kB)
# ...
#
# [notice] A new release of pip is available: 23.0 -> 23.2
# [notice] To update, run: /Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip

# %%
# Importando a lib 'Tabula'
import tabula
from tabula.io import read_pdf
# from tabula import wrapper

# %%
# Lendo a tabela, passando o path do PDF e passando o numero da pagina que possui a tabela que queremos ler.

# table_demonst_1t23 = wrapper.read_pdf("PDFs/demonstrações-contábeis-completas-em-IFRS-Itau-1t23.pdf")
file_path = "PDFs/demonstrações-contábeis-completas-em-IFRS-Itau-1t23.pdf"

tabela_demonstracoes_1t23 = tabula.io.read_pdf(file_path, pages = '11')

# %%
tabela_demonstracoes_1t23[0]
# Out:
#                          Passivo e Patrimônio Líquido  ... 31 /12/2022
# 0                                Passivos Financeiros  ...   1.836.690
# 1                                 Ao Custo Amortizado  ...   1.755.498
# 2                                           Depósitos  ...     871.438
# 3                        Captações no Mercado A berto  ...     293.440
# 4                 Recursos de Mercados lnterbancários  ...     294.587
# 5                 Recursos de Mercados Institucionais  ...     129.382
# 6                         Outros Passivos Financeiros  ...     166.651
# 7                Ao Valor Justo por meio do Resultado  ...      77.508
# 8                                         Derivativos  ...      76.861
# 9                                  Notas Estruturadas  ...          64
# 10                        Outros Passivos Financeiros  ...         583
# 11                       Provisão para Perda Esperada  ...       3.684
# ...

# %% [markdown]
# ### Lendo o 2˚ PDF

# %%
file_path = "PDFs/análise-gerencial-da-operação-e-demonstrações-contábeis-completas-em-BRGAAP.pdf"

tabela_analise_gerencial = tabula.io.read_pdf(file_path, pages = '5')

tabela_analise_gerencial[0]
# Out:
#                  Em R$ milhões (exceto onde indicado)  ...       1T22
# 0                      Resultado Recorrente Gerencial  ...      7.361
# 1                                Produto Bancário (1)  ...     33.035
# 2                     Margem Financeira Gerencial (2)  ...     21.047
# 3   Retorno Recorrente Gerencial sobre o Patrimôni...  ...      20,4%
# 4   Retorno Recorrente Gerencial sobre o Patrimôni...  ...      21,0%
# 5   Retorno Recorrente Gerencial sobre o Ativo Méd...  ...       1,4%
# 6           Índice de Inadimplência (90 dias) - Total  ...       2,6%
# 7          Índice de Inadimplência (90 dias) - Brasil  ...       2,9%
# 8   Índice de Inadimplência (90 dias) - América La...  ...       1,6%
# 9   Índice de Cobertura (Saldo de Provisão Total /...  ...       232%
# 10                      Índice de Eficiência (IE) (6)  ...      41,8%
# 11   Resultado Recorrente Gerencial por Ação (R$) (7)  ...       0,75
# ...

# %% [markdown]
# ## Os 2 PDFs retornou o que foi esperado, como podemos ver, 3 linhas para executar!
