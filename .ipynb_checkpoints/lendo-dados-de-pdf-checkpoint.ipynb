# %% [markdown]
# ## Lendo tabelas dentro de PDFs
#
# ### Vamos testar com 2 PDFs diferentes

# %%
# Vamos baixar a lib 'tabula' para podermos ler os PDF
# !pip install tabula-py
# Out:
# Collecting tabula-py
#   Downloading tabula_py-2.7.0-py3-none-any.whl (12.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 6.3 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pandas>=0.25.3 in /Users/luanartacho/jupyter/lib/python3.9/site-packages (from tabula-py) (1.5.3)
# Requirement already satisfied: numpy in /Users/luanartacho/jupyter/lib/python3.9/site-packages (from tabula-py) (1.24.2)
# Collecting distro (from tabula-py)
#   Downloading distro-1.8.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/luanartacho/jupyter/lib/python3.9/site-packages (from pandas>=0.25.3->tabula-py) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/luanartacho/jupyter/lib/python3.9/site-packages (from pandas>=0.25.3->tabula-py) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /Users/luanartacho/jupyter/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas>=0.25.3->tabula-py) (1.16.0)
# Installing collected packages: distro, tabula-py
# Successfully installed distro-1.8.0 tabula-py-2.7.0

# %%
# Importando a lib 'Tabula'
# import tabula
from tabula.io import read_pdf
# from tabula import wrapper

# %%
# Lendo a tabela, passando o path do PDF e passando o numero da pagina que possui a tabela que queremos ler.

# table_demonst_1t23 = wrapper.read_pdf("PDFs/demonstrações-contábeis-completas-em-IFRS-Itau-1t23.pdf")
file_path = "PDFs/demonstrações-contábeis-completas-em-IFRS-Itau-1t23.pdf"

tabela_demonstracoes_1t23 = tabula.io.read_pdf(file_path, pages = '11')
# Out:
# Got stderr: Jul 20, 2023 12:11:29 AM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider loadDiskCache
# WARNING: New fonts found, font cache will be re-built
# Jul 20, 2023 12:11:29 AM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider <init>
# WARNING: Building on-disk font cache, this may take a while
# Jul 20, 2023 12:11:30 AM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider <init>
# WARNING: Finished building on-disk font cache, found 784 fonts

# %%
tabela_demonstracoes_1t23[0]
# Out:
#                          Passivo e Patrimônio Líquido    Nota 31 /03/2023  \
# 0                                Passivos Financeiros     NaN   1.889.669
# 1                                 Ao Custo Amortizado     NaN   1.801.332
# 2                                           Depósitos      15     914.834
# 3                        Captações no Mercado A berto     17a     294.095
# 4                 Recursos de Mercados lnterbancários     17b     306.233
# 5                 Recursos de Mercados Institucionais     17c     129.365
# 6                         Outros Passivos Financeiros     18b     156.805
# 7                Ao Valor Justo por meio do Resultado     NaN      84.406
# 8                                         Derivativos     6,7      83.572
# 9                                  Notas Estruturadas      16          61
# 10                        Outros Passivos Financeiros     18b         773
# 11                       Provisão para Perda Esperada      10       3.931
# 12                        Compromissos de Empréstimos     NaN       3.116
# 13                              Garantias Financeiras     NaN         815
# 14          Contratos de Seguro e Previdência Privada     27c     239.232
# 15                                          Provisões      29      19.598
# 16                                 Obrigações Fiscais     24c       6.802
# 17  Imposto de Renda e Contribuição Social - Corre...     NaN       1.246
# 18  Imposto de Renda e Contribuição Social - Difer...  24b li         419
# 19                                             Outras     NaN       5.137
# 20                                    Outros Passivos     18b      51.672
# 21                                   Total do Passivo     NaN   2.206.973
#
#    31 /12/2022
# 0    1.836.690
# 1    1.755.498
# 2      871.438
# 3      293.440
# 4      294.587
# 5      129.382
# 6      166.651
# 7       77.508
# 8       76.861
# 9           64
# 10         583
# 11       3.684
# 12       2.874
# 13         810
# 14     233.126
# 15      19.475
# 16       6.773
# 17       2.950
# 18         345
# 19       3.478
# 20      47.895
# 21   2.143.959
